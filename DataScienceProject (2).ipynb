# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#This data was customised in Excel(more on this in my report)
df = pd.read_excel('intern_data2.xlsx', sheet_name='Sheet1')
df.head()
# Out:
#       0  Agriculture, forestry and fishing  Mining and quarrying  \
# 0  1990                            54667.9               46561.7
# 1  1991                            54356.7               47082.0
# 2  1992                            53949.2               47618.5
# 3  1993                            53149.4               47244.1
# 4  1994                            54274.5               42960.3
#
#    Manufacturing  Electricity, gas, steam and air conditioning supply  \
# 0       180059.7                                           217166.6
# 1       181189.9                                           213890.9
# 2       174062.0                                           201849.5
# 3       168507.4                                           184355.7
# 4       170908.6                                           180890.8
#
#    Water supply; sewerage, waste management and remediation activities  \
# 0                                            67600.2
# 1                                            69114.7
# 2                                            69347.9
# 3                                            69583.6
# 4                                            69818.8
#
#    Construction  \
# 0        9499.0
# 1        9476.0
# 2        9590.9
# 3        9737.5
# 4       10194.3
#
#    Wholesale and retail trade; repair of motor vehicles and motorcycles  \
# 0                                            11683.0
# 1                                            12069.7
# 2                                            11890.2
# 3                                            12145.5
# 4                                            12536.3
#
#    Transport and storage  Accommodation and food services  ...  \
# 0                65461.7                           2776.2  ...
# 1                65977.1                           3229.6  ...
# 2                67046.8                           3027.2  ...
# 3                68347.1                           3219.0  ...
# 4                69241.2                           3206.1  ...
#
#    Professional, scientific and technical activities  \
# 0                                             2468.4
# 1                                             2680.2
# 2                                             2602.8
# 3                                             2498.9
# 4                                             2555.4
#
#    Administrative and support service activities  \
# 0                                         2651.2
# 1                                         2801.0
# 2                                         2782.2
# 3                                         2878.9
# 4                                         2980.9
#
#    Public administration and defence; compulsory social security  Education  \
# 0                                            11052.7                 5499.6
# 1                                            10359.0                 5827.4
# 2                                            10504.4                 5970.6
# 3                                            10722.7                 5072.5
# 4                                            10068.0                 4534.3
#
#    Human health and social work activities  \
# 0                                   5756.9
# 1                                   6081.8
# 2                                   6443.9
# 3                                   6126.7
# 4                                   6197.4
#
#    Arts, entertainment and recreation  Other service activities  \
# 0                              2324.9                    1056.4
# 1                              2386.7                    1161.8
# 2                              2031.1                    1130.0
# 3                              2191.2                    1184.9
# 4                              2133.4                    1184.8
#
#    Activities of households as employers; undifferentiated goods and services-producing activities of households for own use  \
# 0                                               58.1
# 1                                               58.5
# 2                                               59.9
# 3                                               61.2
# 4                                               64.5
#
#    Consumer expenditure  Total_per_Year
# 0              142316.6        830696.6
# 1              150965.6        840936.5
# 2              149142.6        821213.1
# 3              154158.6        803452.2
# 4              149261.7        795337.3
#
# [5 rows x 23 columns]

# %%
#ploting year column against total GHG emission of all industry section and groups
plt.style.use('fivethirtyeight')
plt.plot(df[0], df['Total_per_Year'], marker='o', markersize=5, mfc='white')
plt.xlabel('Year')
plt.ylabel('Total Emission(Mass of CO2 in thousand tonnes)')
plt.show()

# %%
x = np.array(df[0])
y = np.array(df['Total_per_Year'])
m, b = np.polyfit(x, y, 1)
plt.plot(df[0], df['Total_per_Year'])
plt.plot(x, m*x+b)
plt.xlabel('Year')
plt.ylabel('Total Emission (Mass of CO2 in thousand tonnes)')
plt.show()

# %%
print('Therefore in five years(2024), total emission = ', (m*2024 + b).round())
#machine learning karvutu pan na thai

print('Estimated year where the GHG emission will be 0 = ', (-b/m).round())
# Out:
# Therefore in five years(2024), total emission =  528671.0
# Estimated year where the GHG emission will be 0 =  2078.0

# %%
#Chi-Squared test
observed = np.array(df['Total_per_Year'])
expected = [(m*x + b) for x in range(1990, 2020, 1)]

chi_squared = (((observed-expected)**2)/expected).sum()
print('The Value of Chi Square = ', chi_squared.round())
# Out:
# The Value of Chi Square =  28962.0

# %%
each_industry_total = list(df.sum()[1:-1].sort_values(ascending=True))

each_industry = ['Activities of households', 'Financial & insurance', 'Real estate activities', 'Information & communication', 
                 'Other service', 'Arts & Entertainment', 'Technical activities', 'Administrative', 'Accommodation', 'Education',
                 'Social work activities', 'Defence & social security', 'Construction', 'Wholesale', 'Mining', 'Water',
                'Agriculture', 'Transport', 'Manufacturing', 'Consumer expenditure', 'Electricity']

plt.barh(each_industry, each_industry_total, )
plt.xlabel('Emission (Mass of CO2 in thousand tonnes)', fontsize=13)
plt.ylabel('Industry', fontsize=13)
plt.show()

# %%
df2 = pd.read_excel('intern_data2.xlsx', sheet_name='Sheet2')
df2.head()
# Out:
#    Year  Total CO2 emissions  Total CH4 emissions  Total N2O emissions  \
# 0  1990             637165.2             129180.0              46984.8
# 1  1991             646096.2             129895.9              47192.9
# 2  1992             631454.6             129735.0              42306.8
# 3  1993             618872.8             128243.0              38106.7
# 4  1994             616015.1             121383.3              38755.8
#
#    Total HFC emissions  Total PFC emissions  Total NF3 emissions  \
# 0              14399.5               1651.4                  0.4
# 1              15008.5               1385.0                  0.5
# 2              15625.8                690.2                  0.5
# 3              16399.5                602.6                  0.6
# 4              17301.0                611.2                  0.7
#
#    Total SF6 emissions
# 0               1315.5
# 1               1357.5
# 2               1399.9
# 3               1227.1
# 4               1270.2

# %%
for i in df2.columns[1:]:
    plt.plot(df2['Year'], df2[i])
plt.legend(labels=['CO2', 'CH4', 'NO2', 'HFC', 'PFC', 'NF3', 'SF6'])
plt.xlabel('Year')
plt.ylabel('Total Emission (Mass of CO2 in thousand tonnes)')
plt.show()

# %%
each_GHG_total = list(df2.sum()[1:])
GHG=['CO2', 'CH4', 'NO2', 'HFC', 'PFC', 'NF3', 'SF6']
plt.bar(GHG, each_GHG_total, color='black')#444444
plt.xlabel('GHG', fontsize=15)
plt.ylabel('Emission (Mass of CO2 in thousand tonnes)', fontsize=15)
plt.title('Total Emission of each GHG till date', fontsize=15)
plt.show()
